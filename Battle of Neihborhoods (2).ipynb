# %% [markdown]
# # Introduction

# %% [markdown]
# This project tries to analyse which neighbourhood to live in depending on their accessiblity, education facilities, healthcare, social life, its crime rates etc

# %% [markdown]
# # Business Problem

# %% [markdown]
# This aims to help people who are deciding which neighbourhood is better to live in.
#
# This mainly depends on the facilities, nearness to shoppong centres, family life, social life, crime rates etc. which are a few of many different factors which people consider before moving into a new neighbourhood.

# %% [markdown]
# # Data Description

# %% [markdown]
# In this analysis, the data used is of 2 the neighbourhoods of Toronto and Ontario. The indicators which will poin to the better neighbourhood analysed in this project are the narness to the closest shopping centre, education facilities, health index and crime rates.

# %%
import pandas as pd

# %%
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
wiki_url = requests.get(url)
wiki_url
# Out:
# <Response [200]>

# %%
wiki_data = pd.read_html(wiki_url.text)
wiki_data
# Out:
# [    Postal Code           Borough  \
#  0           M1A      Not assigned
#  1           M2A      Not assigned
#  2           M3A        North York
#  3           M4A        North York
#  4           M5A  Downtown Toronto
#  ..          ...               ...
#  175         M5Z      Not assigned
#  176         M6Z      Not assigned
#  177         M7Z      Not assigned
#  178         M8Z         Etobicoke
#  179         M9Z      Not assigned
#
#                                           Neighbourhood
#  0                                         Not assigned
#  1                                         Not assigned
#  2                                            Parkwoods
#  3                                     Victoria Village
#  4                            Regent Park, Harbourfront
#  ..                                                 ...
#  175                                       Not assigned
#  176                                       Not assigned
# ...

# %%
len(wiki_data), type(wiki_data)
# Out:
# (3, list)

# %%
wiki_data = wiki_data[0]
wiki_data
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %%
df = wiki_data[wiki_data["Borough"] != "Not assigned"]
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %%
df = df.groupby(['Postal Code']).head()
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %%
df.Neighbourhood.str.count("Not assigned").sum()
# Out:
# 0

# %%
df.drop(['index'], axis = 'columns', inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-acba62089dae> in <module>
# ----> 1 df.drop(['index'], axis = 'columns', inplace = True)
#       2 df
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.shape
# Out:
# (103, 3)

# %%
pip install geocoder
# Out:
# ...
#      |████████████████████████████████| 98 kB 7.4 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# df.describe()

# %% [markdown]
# # Conclusion

# %%
Therefore, looking a this data, the person choosing to shift into a neighbourhood can decide which neighbourhood is better to move into.
# Out:
#   File "<ipython-input-17-cf1712cf57c1>", line 1
#     Therefore, looking a this data, the person choosing to shift into a neighbourhood can decide which neighbourhood is better to move into.
#                        ^
# SyntaxError: invalid syntax
